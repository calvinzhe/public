# %%
data(InsectSprays)

# %%
dim(InsectSprays)
# Out:
# [1] 72  2

# %%
table(InsectSprays[,"spray"])
# Out:
#  A  B  C  D  E  F
# 12 12 12 12 12 12

# %%
pie(table(InsectSprays[,"spray"]))
# Out:
# plot without title

# %%
summary(InsectSprays[,"count"])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    3.00    7.00    9.50   14.25   26.00

# %%
hist(InsectSprays[,"count"],xlab="Insect Counts",main="")
# Out:
# Plot with title ""

# %%
plot(count~spray, data=InsectSprays, xlab="Type of Insecticide", ylab="Counts of Insects")
# Out:
# plot without title

# %%
anova(lm(count~spray, data=InsectSprays))
# Out:
#           Df Sum Sq   Mean Sq   F value  Pr(>F)
# spray      5 2668.833 533.76667 34.70228 3.182584e-17
# Residuals 66 1015.167  15.38131       NA           NA
